# %% [markdown]
# ## IMPORTING PACKAGES AND DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('matches.csv')
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# ## EXPLORING DATA

# %%
df[df['umpire3'].isnull()]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df=df.drop(columns=['umpire3'])
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000

# %%
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               7
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             3
# win_by_runs        0
# win_by_wickets     0
# player_of_match    3
# venue              0
# umpire1            1
# umpire2            1
# dtype: int64

# %%
df.fillna({'umpire1':'Nitin Menon'},inplace=True)
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               7
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             3
# win_by_runs        0
# win_by_wickets     0
# player_of_match    3
# venue              0
# umpire1            0
# umpire2            1
# dtype: int64

# %%
df.fillna({'umpire2':'Kumar Dharmasena'},inplace=True)
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               7
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             3
# win_by_runs        0
# win_by_wickets     0
# player_of_match    3
# venue              0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
df.fillna({'city':'Mumbai'},inplace=True)
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             3
# win_by_runs        0
# win_by_wickets     0
# player_of_match    3
# venue              0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
df[df['winner'].isnull()]
# Out:
#       id  season       city        date                        team1  \
# 300  301    2011      Delhi  2011-05-21             Delhi Daredevils
# 545  546    2015  Bangalore  2015-04-29  Royal Challengers Bangalore
# 570  571    2015  Bangalore  2015-05-17             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 300                Pune Warriors             Delhi Daredevils           bat
# 545             Rajasthan Royals             Rajasthan Royals         field
# 570  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# 300  no result           0    NaN            0               0
# 545  no result           0    NaN            0               0
# 570  no result           0    NaN            0               0
#
#     player_of_match                  venue          umpire1       umpire2
# ...

# %%
df[df['player_of_match'].isnull()]
# Out:
#       id  season       city        date                        team1  \
# 300  301    2011      Delhi  2011-05-21             Delhi Daredevils
# 545  546    2015  Bangalore  2015-04-29  Royal Challengers Bangalore
# 570  571    2015  Bangalore  2015-05-17             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 300                Pune Warriors             Delhi Daredevils           bat
# 545             Rajasthan Royals             Rajasthan Royals         field
# 570  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#         result  dl_applied winner  win_by_runs  win_by_wickets  \
# 300  no result           0    NaN            0               0
# 545  no result           0    NaN            0               0
# 570  no result           0    NaN            0               0
#
#     player_of_match                  venue          umpire1       umpire2
# ...

# %%
df.fillna({'winner':'Unavailable','player_of_match':'Unavailable'},inplace=True)
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# dtype: int64

# %% [markdown]
# ## FINDING PLAYER WITH MOST NO.OF.PLAYER OF MATCH

# %%
df['player_of_match'].value_counts().head(15)
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# SK Raina          14
# RG Sharma         14
# MS Dhoni          13
# G Gambhir         13
# AM Rahane         12
# MEK Hussey        12
# V Sehwag          11
# V Kohli           11
# DR Smith          11
# SR Watson         10
# JH Kallis         10
# Name: player_of_match, dtype: int64

# %%
x=list(df['player_of_match'].value_counts().head(10).keys())
x
# Out:
# ['CH Gayle',
#  'YK Pathan',
#  'AB de Villiers',
#  'DA Warner',
#  'SK Raina',
#  'RG Sharma',
#  'MS Dhoni',
#  'G Gambhir',
#  'AM Rahane',
#  'MEK Hussey']

# %%
y=list(df['player_of_match'].value_counts().head(10))
y
# Out:
# [18, 16, 15, 15, 14, 14, 13, 13, 12, 12]

# %%
plt.figure(figsize=(15,10))
plt.bar(x,y,color=['red','yellow','green','black','pink','blue','orange','violet','Indigo','Silver'])
plt.grid(True)
plt.title('Man of the Match')
plt.xlabel('Name of the Players')
plt.ylabel('Number of Awards')
plt.show()

# %% [markdown]
# ## TEAMS WINNING BATTING FIRST

# %%
batting_first=df[df['win_by_runs']!=0]
batting_first
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 13    14    2017        Kolkata  2017-04-15        Kolkata Knight Riders
# 14    15    2017          Delhi  2017-04-15             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 625  626    2016      Bangalore  2016-05-18  Royal Challengers Bangalore
# 630  631    2016        Kolkata  2016-05-22        Kolkata Knight Riders
# 633  634    2016          Delhi  2016-05-25          Sunrisers Hyderabad
# 635  636    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
batting_first.head(20)
# Out:
#     id  season        city        date                        team1  \
# 0    1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4    5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 8    9    2017        Pune  2017-04-11             Delhi Daredevils
# 13  14    2017     Kolkata  2017-04-15        Kolkata Knight Riders
# 14  15    2017       Delhi  2017-04-15             Delhi Daredevils
# 16  17    2017   Bangalore  2017-04-16       Rising Pune Supergiant
# 18  19    2017   Hyderabad  2017-04-17          Sunrisers Hyderabad
# 19  20    2017      Rajkot  2017-04-18  Royal Challengers Bangalore
# 20  21    2017   Hyderabad  2017-04-19          Sunrisers Hyderabad
# 23  24    2017      Mumbai  2017-04-22               Mumbai Indians
# 25  26    2017      Rajkot  2017-04-23              Kings XI Punjab
# 26  27    2017     Kolkata  2017-04-23        Kolkata Knight Riders
# 27  28    2017      Mumbai  2017-04-24       Rising Pune Supergiant
# ...

# %%
plt.figure(figsize=(7,5))
sns.histplot(x = "win_by_runs",data = batting_first, kde = True,color='purple',bins=10)
plt.grid(True)
plt.title('Distribution of Win by Runs')
plt.show()

# %%
batting_first['winner'].value_counts()
# Out:
# Mumbai Indians                 47
# Chennai Super Kings            46
# Kings XI Punjab                32
# Kolkata Knight Riders          31
# Royal Challengers Bangalore    30
# Sunrisers Hyderabad            23
# Rajasthan Royals               23
# Delhi Daredevils               21
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
list(batting_first['winner'].value_counts().keys())
# Out:
# ['Mumbai Indians',
#  'Chennai Super Kings',
#  'Kings XI Punjab',
#  'Kolkata Knight Riders',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad',
#  'Rajasthan Royals',
#  'Delhi Daredevils',
#  'Deccan Chargers',
#  'Pune Warriors',
#  'Rising Pune Supergiant',
#  'Kochi Tuskers Kerala',
#  'Rising Pune Supergiants',
#  'Gujarat Lions']

# %%
list(batting_first['winner'].value_counts())
# Out:
# [47, 46, 32, 31, 30, 23, 23, 21, 18, 6, 5, 2, 2, 1]

# %%
plt.figure(figsize=(7,7))
sns.countplot(y='winner',order=batting_first['winner'].value_counts().index[0:15],data=batting_first,palette = "Set2")
plt.title('Winning Teams After Batting First ')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,12))
myexplode = [0.05, 0.05, 0.05, 0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05]
plt.pie(list(batting_first['winner'].value_counts()),labels=list(batting_first['winner'].value_counts().keys()),autopct='%0.1f%%',explode = myexplode,shadow = True)
plt.show()

# %% [markdown]
# ## TEAMS WINNING BATTING SECOND

# %%
bat_second=df[df['win_by_wickets']!=0]
bat_second
# Out:
#       id  season           city        date                   team1  \
# 1      2    2017           Pune  2017-04-06          Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07           Gujarat Lions
# 3      4    2017         Indore  2017-04-08  Rising Pune Supergiant
# 5      6    2017      Hyderabad  2017-04-09           Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09   Kolkata Knight Riders
# ..   ...     ...            ...         ...                     ...
# 628  629    2016  Visakhapatnam  2016-05-21         Kings XI Punjab
# 629  630    2016         Kanpur  2016-05-21          Mumbai Indians
# 631  632    2016         Raipur  2016-05-22        Delhi Daredevils
# 632  633    2016      Bangalore  2016-05-24           Gujarat Lions
# 634  635    2016          Delhi  2016-05-27           Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
bat_second.head(20)
# Out:
#     id  season        city        date                        team1  \
# 1    2    2017        Pune  2017-04-06               Mumbai Indians
# 2    3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3    4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 5    6    2017   Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017      Mumbai  2017-04-09        Kolkata Knight Riders
# 7    8    2017      Indore  2017-04-10  Royal Challengers Bangalore
# 9   10    2017      Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 11  12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017      Rajkot  2017-04-14       Rising Pune Supergiant
# 15  16    2017      Mumbai  2017-04-16                Gujarat Lions
# 17  18    2017       Delhi  2017-04-17             Delhi Daredevils
# 21  22    2017      Indore  2017-04-20              Kings XI Punjab
# ...

# %%
bat_second['win_by_wickets'].value_counts()
# Out:
# 7     70
# 6     68
# 5     57
# 8     48
# 4     34
# 9     32
# 3     15
# 10    10
# 2      4
# 1      1
# Name: win_by_wickets, dtype: int64

# %%
plt.figure(figsize=(7,5))
sns.histplot(x = "win_by_wickets",data = bat_second, kde = True,color='Red',bins=17)
plt.grid(True)
plt.title('Distribution of Win by Wickets')
plt.show()

# %%
bat_second['winner'].value_counts()
# Out:
# Kolkata Knight Riders          46
# Mumbai Indians                 44
# Royal Challengers Bangalore    42
# Delhi Daredevils               41
# Rajasthan Royals               38
# Kings XI Punjab                36
# Chennai Super Kings            33
# Sunrisers Hyderabad            18
# Gujarat Lions                  12
# Deccan Chargers                11
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
list(bat_second['winner'].value_counts().keys())
# Out:
# ['Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Delhi Daredevils',
#  'Rajasthan Royals',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Sunrisers Hyderabad',
#  'Gujarat Lions',
#  'Deccan Chargers',
#  'Pune Warriors',
#  'Rising Pune Supergiant',
#  'Kochi Tuskers Kerala',
#  'Rising Pune Supergiants']

# %%
plt.figure(figsize=(7,7))
sns.countplot(y='winner',order=bat_second['winner'].value_counts().index[0:15],data=bat_second,palette = "Set1")
plt.title('Winning Teams After Batting Second ')
plt.grid(True)
plt.show()

# %% [markdown]
# ## COMPARISON BETWEEN WINNING FIRST AND WINNING SECOND

# %%
x=len(batting_first.value_counts())
x
# Out:
# 287

# %%
y=len(bat_second.value_counts())
y
# Out:
# 339

# %%
x = 287
y = 339


plt.figure(figsize=(20,25))

plt.bar(0, x, color='red', label='Winning Teams Batting First')
plt.bar(1, y, color='blue', label='Winning Teams Batting Second')

plt.xticks([0, 1], ['x', 'y']) 
plt.ylabel('Values')
plt.title('Winning Comparison:Bat First Vs Bat Second')
plt.legend()


plt.show()
